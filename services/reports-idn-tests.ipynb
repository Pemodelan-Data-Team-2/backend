# %%
import pandas as pd
from pickle import load, dump

from reports import CountryReports

# %% [markdown]
# ## Test Reports

# %%
idn_instance = CountryReports('idn')
# Out:
# Accessing DC: idn

# %%
with open('./idn_test/patient_admissions_by_country.pkl', 'rb') as fh:
    patient_admissions_by_country = load(fh)

# %%
with open('./idn_test/patient_admissions_by_state.pkl', 'rb') as fh:
    patient_admissions_by_state = load(fh)

# %% [markdown]
# ### Line chart data

# %% [markdown]
# #### Revenues

# %%
patient_admissions_revenues_per_annum = idn_instance.patient_admissions_revenues_per_annum(patient_admissions_by_country)
patient_admissions_revenues_per_annum
# Out:
# {'id': 'idn',
#  'data': [{'x': '2012', 'y': 485244.82},
#   {'x': '2013', 'y': 685427.55},
#   {'x': '2014', 'y': 575219.28},
#   {'x': '2015', 'y': 459797.58},
#   {'x': '2016', 'y': 412617.45},
#   {'x': '2017', 'y': 592859.3},
#   {'x': '2018', 'y': 548248.78},
#   {'x': '2019', 'y': 444777.59},
#   {'x': '2020', 'y': 598127.75},
#   {'x': '2021', 'y': 502389.72},
#   {'x': '2022', 'y': 416671.38}]}

# %%
patient_admissions_revenues_per_month = idn_instance.patient_admissions_revenues_per_month(patient_admissions_by_country, 2021)
patient_admissions_revenues_per_month
# Out:
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['admitted_date'].dt.month
# {'id': 'idn',
#  'data': [{'x': '1', 'y': 45296.47},
#   {'x': '2', 'y': 6977.16},
#   {'x': '3', 'y': 82474.97},
#   {'x': '4', 'y': 15042.630000000001},
#   {'x': '5', 'y': 26872.420000000002},
#   {'x': '6', 'y': 48621.56},
#   {'x': '7', 'y': 46718.92},
#   {'x': '8', 'y': 56960.37},
#   {'x': '9', 'y': 44463.479999999996},
#   {'x': '10', 'y': 29306.4},
#   {'x': '11', 'y': 61831.32},
#   {'x': '12', 'y': 37824.020000000004}]}

# %%
patient_admissions_revenues_per_quarter = idn_instance.patient_admissions_revenues_per_quarter(patient_admissions_by_country, 2021)
patient_admissions_revenues_per_quarter
# Out:
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['admitted_date'].dt.quarter
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['quarter'].map(quarter_dct)
# {'id': 'idn',
#  'data': [{'x': 'Q1', 'y': 134748.6},
#   {'x': 'Q2', 'y': 90536.61},
#   {'x': 'Q3', 'y': 148142.77},
#   {'x': 'Q4', 'y': 128961.74}]}

# %% [markdown]
# ### DataFrame formats
# #### Total admitted patients

# %%
patient_admissions_per_annum = idn_instance.patient_admissions_per_annum(patient_admissions_by_country)
patient_admissions_per_annum
# Out:
#     year  total_admitted_patients
# 0   2012                       94
# 1   2013                       95
# 2   2014                       82
# 3   2015                       86
# 4   2016                       79
# 5   2017                       91
# 6   2018                       82
# 7   2019                       80
# 8   2020                       92
# 9   2021                       84
# 10  2022                       92

# %%
patient_admissions_per_month = idn_instance.patient_admissions_per_month(patient_admissions_by_country, 2021)
patient_admissions_per_month
# Out:
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['admitted_date'].dt.month
#     month  total_admitted_patients
# 0       1                        8
# 1       2                        1
# 2       3                        9
# 3       4                        4
# 4       5                        8
# 5       6                        9
# 6       7                        8
# 7       8                        6
# 8       9                        7
# 9      10                        6
# 10     11                       10
# 11     12                        8

# %%
patient_admissions_per_quarter = idn_instance.patient_admissions_per_quarter(patient_admissions_by_country, 2021)
patient_admissions_per_quarter
# Out:
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['admitted_date'].dt.quarter
# C:\Users\USER\Documents\IF5170\backend\services\reports.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['quarter'].map(quarter_dct)
#   quarter  total_admitted_patients
# 0      Q1                       18
# 1      Q2                       21
# 2      Q3                       21
# ...

# %% [markdown]
# ### Table Data

# %%
revenues_by_state_per_annum = idn_instance.revenues_by_state_per_annum(patient_admissions_by_state)
revenues_by_state_per_annum
# Out:
# [{'year': 2012, 'state': 'B', 'total_revenues': 242034.73, 'Country': 'idn'},
#  {'year': 2012, 'state': 'J', 'total_revenues': 243210.09, 'Country': 'idn'},
#  {'year': 2013, 'state': 'B', 'total_revenues': 213461.12, 'Country': 'idn'},
#  {'year': 2013, 'state': 'J', 'total_revenues': 471966.43, 'Country': 'idn'},
#  {'year': 2014, 'state': 'B', 'total_revenues': 272386.82, 'Country': 'idn'},
#  {'year': 2014, 'state': 'J', 'total_revenues': 302832.46, 'Country': 'idn'},
#  {'year': 2015,
#   'state': 'B',
#   'total_revenues': 247229.66999999998,
#   'Country': 'idn'},
#  {'year': 2015, 'state': 'J', 'total_revenues': 212567.91, 'Country': 'idn'},
#  {'year': 2016, 'state': 'B', 'total_revenues': 206160.83, 'Country': 'idn'},
#  {'year': 2016, 'state': 'J', 'total_revenues': 206456.62, 'Country': 'idn'},
#  {'year': 2017, 'state': 'B', 'total_revenues': 255076.15, 'Country': 'idn'},
#  {'year': 2017, 'state': 'J', 'total_revenues': 337783.15, 'Country': 'idn'},
# ...

# %%
patient_admission_by_state_per_year = idn_instance.patient_admission_by_state_per_year(patient_admissions_by_state)
patient_admission_by_state_per_year
# Out:
# [{'year': 2012, 'state': 'B', 'total_admitted_patients': 44, 'Country': 'idn'},
#  {'year': 2012, 'state': 'J', 'total_admitted_patients': 50, 'Country': 'idn'},
#  {'year': 2013, 'state': 'B', 'total_admitted_patients': 40, 'Country': 'idn'},
#  {'year': 2013, 'state': 'J', 'total_admitted_patients': 55, 'Country': 'idn'},
#  {'year': 2014, 'state': 'B', 'total_admitted_patients': 45, 'Country': 'idn'},
#  {'year': 2014, 'state': 'J', 'total_admitted_patients': 37, 'Country': 'idn'},
#  {'year': 2015, 'state': 'B', 'total_admitted_patients': 40, 'Country': 'idn'},
#  {'year': 2015, 'state': 'J', 'total_admitted_patients': 46, 'Country': 'idn'},
#  {'year': 2016, 'state': 'B', 'total_admitted_patients': 40, 'Country': 'idn'},
#  {'year': 2016, 'state': 'J', 'total_admitted_patients': 39, 'Country': 'idn'},
#  {'year': 2017, 'state': 'B', 'total_admitted_patients': 39, 'Country': 'idn'},
#  {'year': 2017, 'state': 'J', 'total_admitted_patients': 52, 'Country': 'idn'},
# ...

# %%
patient_admissions_by_country
# Out:
#     country  admission_id                                    admitted_causes  \
# 0       IDN  adm-idn-0003  Dissecting aortic aneurysm tearing and dilatio...
# 1       IDN  adm-idn-0008          Inhaled foreign body in respiratory tract
# 2       IDN  adm-idn-0029           Mitral regurgitation leaking heart valve
# 3       IDN  adm-idn-0058  Symptomatic dermatographism exaggerated skin r...
# 4       IDN  adm-idn-0059             Colic prolonged infant crying episodes
# ..      ...           ...                                                ...
# 952     IDN  adm-idn-9947            Epiglottitis severe throat inflammation
# 953     IDN  adm-idn-9982                                          Head lice
# 954     IDN  adm-idn-9985                      Tonsillar cancer tumor tongue
# 955     IDN  adm-idn-9993  Vesicovaginal fistula connection between the b...
# 956     IDN  adm-idn-9997  Polycystic kidney disease inherited kidney dis...
#
# ...

# %%
room_occupancy_by_room_type_per_year = idn_instance.room_occupancy_by_room_type_per_year(patient_admissions_by_country)
room_occupancy_by_room_type_per_year
# Out:
# [{'year': 2012,
#   'Class I': 13,
#   'Class II': 34,
#   'Class III': 15,
#   'VIP': 11,
#   'VVIP': 21},
#  {'year': 2013,
#   'Class I': 19,
#   'Class II': 22,
#   'Class III': 11,
#   'VIP': 25,
#   'VVIP': 18},
#  {'year': 2014,
#   'Class I': 19,
#   'Class II': 20,
#   'Class III': 14,
#   'VIP': 10,
#   'VVIP': 19},
#  {'year': 2015,
#   'Class I': 15,
#   'Class II': 33,
#   'Class III': 13,
#   'VIP': 15,
#   'VVIP': 10},
#  {'year': 2016,
#   'Class I': 15,
#   'Class II': 23,
#   'Class III': 17,
#   'VIP': 19,
#   'VVIP': 5},
#  {'year': 2017,
#   'Class I': 27,
#   'Class II': 15,
#   'Class III': 17,
#   'VIP': 9,
#   'VVIP': 23},
#  {'year': 2018,
#   'Class I': 17,
#   'Class II': 19,
#   'Class III': 10,
#   'VIP': 26,
#   'VVIP': 10},
#  {'year': 2019,
#   'Class I': 20,
#   'Class II': 19,
#   'Class III': 13,
#   'VIP': 14,
#   'VVIP': 14},
#  {'year': 2020,
#   'Class I': 20,
#   'Class II': 18,
#   'Class III': 19,
#   'VIP': 20,
#   'VVIP': 15},
# ...
